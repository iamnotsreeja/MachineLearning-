# %%
import matplotlib.pyplot as plt
import seaborn as src ; src.set()
import numpy as np

# %%
from sklearn.datasets import make_blobs
x,y =make_blobs(n_samples = 50 , centers = 3 , cluster_std = 1.2)
plt.scatter(x[:,0],x[:,1],c=y,cmap = 'autumn')

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as src ; src.set()

# %%
from sklearn.datasets import make_blobs
x,y = make_blobs(n_samples = 500 , centers = 4 , cluster_std = 0.9)
plt.scatter(x[:,0],x[:,1],c=y,cmap = 'bone')

# %%
import matplotlib.pyplot as plt
import numpy as np 
import seaborn as src ; src.set()

# %%
from sklearn.datasets import make_blobs
x,y = make_blobs(n_samples = 100 ,centers = 5,cluster_std = 1.2)
plt.scatter(x[:,0],x[:,1],c=y,cmap = 'spring')

# %%
import matplotlib.pyplot as plt
import numpy as np 
import seaborn as src; src.set()

# %%
from sklearn.datasets import make_blobs 
x,y = make_blobs(n_samples = 200 , centers = 7 , cluster_std = 0.8)
plt.scatter(x[:,0],x[:,1],c=y,cmap = 'copper')
