# %%
import matplotlib.pyplot as plt
import seaborn as sns ; sns.set()
import numpy as np

# %%
N = 20
x = np.arange(N)
y = 3*x +(20*np.random.randn(N))
plt.scatter(x,y)

# %%
from sklearn.linear_model import LinearRegression 
model =  LinearRegression (fit_intercept = True)
model.fit(x[:,np.newaxis],y)
yfit = model.predict(x[:,np.newaxis])
plt.scatter(x,y)
plt.plot(x,yfit, color = 'red')

# %%
import matplotlib.pyplot as plt
import seaborn as src;src.set()
import numpy as np

# %%
N = 100 
x = np.arange(N)
y = x-7 + (50*np.random.rand(N))
plt.scatter(x,y)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression (fit_intercept = True)
model.fit(x[:,np.newaxis],y)
yfit = model.predict(x[:,np.newaxis])
plt.scatter(x,y)
plt.plot(x,yfit,color = 'yellow')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
N = 10
x = np.arange(N)
y = 5*x-12 + (2*np.random.randn(N)+11)
plt.scatter(x,y)

# %%
from sklearn.linear_model import LinearRegression 
model = LinearRegression (fit_intercept = True)
model.fit(x[:,np.newaxis],y)
yfit = model.predict(x[:,np.newaxis])
plt.scatter(x,y)
plt.plot(x,yfit,color="black")

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
N = 20
x = np.arange(N)
y = 4*x - 7 +(5*np.random.randn(N))
plt.scatter(x,y)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression(fit_intercept = True)
model.fit(x[:,np.newaxis],y)
plt.scatter(x,y)
yfit = model.predict(x[:,np.newaxis])
plt.plot(x,yfit,color = 'red')
